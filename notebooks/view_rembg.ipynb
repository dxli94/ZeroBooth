# %%
import random

from rembg import remove
from dataset import load_dataset
from lavis.datasets.builders import load_dataset

# %%
dataset = load_dataset(
    name="imagenet",
    cfg_path="/export/home/workspace/LAVIS/lavis/configs/datasets/imagenet/defaults_val.yaml",
)["val"]

# %%
print(len(dataset))
# Out:
# 50000

# %%
num_examples = 3

for i in range(num_examples):
    rnd_index = random.randint(0, len(dataset) - 1)

    example = dataset[rnd_index]
    print(example.keys())
    display(example["image"])
    display(example["text_input"])

    output = remove(example["image"])

    display(output)

    output = remove(example["image"], only_mask=True, post_process_mask=False)

    display(output)
# Out:
# dict_keys(['image', 'label', 'text_input', 'image_id', 'instance_id'])
# <PIL.Image.Image image mode=RGB size=500x375>
# 'school bus, bus, autobus, coach, charabanc, double-decker, jitney, motorbus, motorcoach, omnibus, passenger vehicle'
# <PIL.Image.Image image mode=RGBA size=500x375>
# <PIL.Image.Image image mode=L size=500x375>
# dict_keys(['image', 'label', 'text_input', 'image_id', 'instance_id'])
# <PIL.Image.Image image mode=RGB size=500x410>
# 'Dobermann, pinscher'
# <PIL.Image.Image image mode=RGBA size=500x410>
# <PIL.Image.Image image mode=L size=500x410>
# dict_keys(['image', 'label', 'text_input', 'image_id', 'instance_id'])
# <PIL.Image.Image image mode=RGB size=500x490>
# 'bulbul, nightingale, Luscinia megarhynchos'
# <PIL.Image.Image image mode=RGBA size=500x490>
# <PIL.Image.Image image mode=L size=500x490>
